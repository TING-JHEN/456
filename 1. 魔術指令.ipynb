# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([-2, 10, 3])

# %%
x = randn(10)

# %%
x
# Out:
# array([ 0.17725743,  1.08646456,  0.08745493, -0.60480094,  0.62726796,
#        -0.93169924,  0.41479232,  0.01641082,  1.15036221, -0.07169495])

# %%
plot(x)
